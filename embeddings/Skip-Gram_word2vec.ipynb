# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %%
len(text)
# Out:
# 100000000

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random
import math


def keep_probability_article(count):
    t = 1e-3 #1e-5 
    frequency = count / len(int_words)
    return (math.sqrt(frequency / t) + 1) * (t / frequency)

def keep_probability_project(count):

    threshold = 1e-5 
    frequency = count / len(int_words)
    return math.sqrt(threshold / frequency) 
    

word_to_keep_probablility = {i : keep_probability_project(count) for i, count in Counter(int_words).items()}

train_words = [i for i in int_words if word_to_keep_probablility[i] > random.random()]

# %%
len(train_words)
# Out:
# 4627059

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    c = random.randint(1, window_size + 1)

    pre = words[max(0,idx - c) : idx]

    post = words[idx + 1 : idx + c + 1]

    return list(set(pre + post)) #remove duplicate words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None,1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1), name='embedding')
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab,n_embedding], stddev=0.1), name='softmax_w')
    softmax_b = tf.Variable(tf.zeros([n_vocab]), name='softmax_b')
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        weights=softmax_w, 
        biases=softmax_b, 
        labels=labels, 
        inputs=embed,
        num_sampled = n_sampled,
        num_classes = n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = tf.divide(embedding,norm) #embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6724 0.0338 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6225 0.0322 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5325 0.0325 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5625 0.0325 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5286 0.0313 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5231 0.0315 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5276 0.0339 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5705 0.0318 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5091 0.0319 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4101 0.0321 sec/batch
# Nearest to however: tuscan, apg, paraphrase, fg, everything, sarpedon, crosley, yellowstone,
# Nearest to than: clos, genosha, swingarm, attribution, azo, bing, form, limfjord,
# Nearest to who: monophosphate, loi, pequod, attitudes, anxiolytic, luka, bodybuilding, giraud,
# Nearest to been: munich, majors, husk, eschrichtius, patronage, spellman, southend, presidencia,
# Nearest to in: spellings, rigoletto, loyal, intimidating, crystalline, ltspkr, donating, qxd,
# Nearest to has: parishes, hind, larp, organelles, emulsion, plas, helms, rated,
# Nearest to seven: bayer, precaution, azerbaijan, fabio, qt, gottorp, osr, utr,
# Nearest to also: roque, expandable, will, rust, naboth, scottish, tunguska, gen,
# Nearest to institute: sultanates, sauerkraut, dunes, balke, brandauer, talia, cz, candle,
# Nearest to placed: superclass, administers, piazza, kushner, sophisticated, messe, suzerain, scuola,
# Nearest to square: michell, verner, arslan, angst, paradox, conscience, catheter, dits,
# Nearest to arts: generalized, cagayan, approaches, whipped, alphonso, anglo, cryonics, gue,
# Nearest to applications: advisory, oxidizing, penicillin, elsevier, twigs, stalls, edging, manually,
# Nearest to woman: greene, hyatt, ahmet, ancients, lauter, esteemed, delicately, universitaire,
# Nearest to magazine: bottles, midshipman, dalek, faye, chemically, pir, surrounding, kitty,
# Nearest to scale: touman, oplus, euler, insular, lookout, ruud, volker, gayle,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5010 0.0331 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3732 0.0319 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3578 0.0325 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2358 0.0316 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1750 0.0325 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1832 0.0316 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0666 0.0322 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0459 0.0325 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9856 0.0328 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9591 0.0330 sec/batch
# Nearest to however: everything, paraphrase, tuscan, apg, fg, road, public, special,
# Nearest to than: form, azo, attribution, clos, repression, transportation, bing, has,
# Nearest to who: specific, attitudes, programmes, brownie, flurry, bank, bodybuilding, loi,
# Nearest to been: majors, munich, husk, a, patronage, thick, moving, manipulated,
# Nearest to in: spellings, loyal, difference, crystalline, rigoletto, namely, equal, intimidating,
# Nearest to has: parishes, influence, hind, than, organelles, rated, decreasing, other,
# Nearest to seven: four, zaire, bayer, resistor, selling, improve, fabio, azerbaijan,
# Nearest to also: will, rust, highest, expandable, roque, finishing, new, honour,
# Nearest to institute: sultanates, cz, candle, commercial, cooperate, harmon, talia, dunes,
# Nearest to placed: agriculture, sophisticated, little, kushner, consensus, scuola, superclass, recording,
# Nearest to square: fired, greatly, paradox, catheter, tiberius, verner, jehoiakim, political,
# Nearest to arts: generalized, approaches, anglo, whipped, role, achromatopsia, relief, cryonics,
# Nearest to applications: advisory, manually, opposed, elsevier, twigs, closely, subordinate, minorities,
# Nearest to woman: hyatt, greene, opening, ahmet, ancients, esteemed, dark, created,
# Nearest to magazine: surrounding, bottles, dalek, chemically, versus, midshipman, kitty, century,
# Nearest to scale: insular, euler, touman, danish, oplus, lookout, katana, dvina,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9511 0.0330 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8872 0.0324 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8952 0.0333 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8512 0.0329 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8141 0.0331 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8339 0.0327 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8057 0.0331 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7831 0.0323 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7726 0.0316 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7876 0.0320 sec/batch
# Nearest to however: everything, fg, paraphrase, apg, tuscan, sarpedon, ayla, special,
# Nearest to than: form, attribution, azo, clos, napoleonic, inventive, repression, genosha,
# Nearest to who: attitudes, immigrant, programmes, bank, brownie, loi, specific, flurry,
# Nearest to been: munich, majors, suit, a, manipulated, patronage, fees, husk,
# Nearest to in: spellings, loyal, rigoletto, crystalline, intimidating, difference, satanism, namely,
# Nearest to has: parishes, hind, organelles, treaties, influence, other, fool, houses,
# Nearest to seven: four, three, sherlock, bayer, zaire, fabio, workshop, deceit,
# Nearest to also: will, rust, roque, expandable, highest, finishing, gen, dies,
# Nearest to institute: sultanates, commercial, candle, cooperate, cz, harmon, talia, objections,
# Nearest to placed: sophisticated, agriculture, little, consensus, piazza, recording, upheld, ie,
# Nearest to square: verner, paradox, greatly, fired, catheter, conscience, tiberius, peninsular,
# Nearest to arts: generalized, approaches, anglo, whipped, relief, emmy, postwar, role,
# Nearest to applications: advisory, manually, opposed, subordinate, elsevier, twigs, minorities, closely,
# Nearest to woman: greene, opening, hyatt, ahmet, portray, esteemed, dark, ancients,
# Nearest to magazine: bottles, chemically, surrounding, kitty, dalek, versus, midshipman, faye,
# Nearest to scale: euler, insular, idiom, lookout, gangsta, touman, doesn, falange,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7841 0.0351 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7612 0.0329 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7210 0.0324 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7225 0.0321 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7368 0.0321 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7089 0.0324 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6940 0.0321 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7389 0.0315 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7101 0.0330 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6905 0.0326 sec/batch
# Nearest to however: everything, fg, tuscan, apg, paraphrase, ayla, bows, pretext,
# Nearest to than: azo, inventive, form, attribution, repression, genosha, napoleonic, clos,
# Nearest to who: brownie, immigrant, attitudes, programmes, chapel, loi, mayo, pequod,
# Nearest to been: majors, munich, a, fees, suit, manipulated, patronage, husk,
# Nearest to in: loyal, spellings, rigoletto, reintroduce, satanism, intimidating, namely, donating,
# Nearest to has: parishes, hind, larp, influence, treaties, organelles, equivocal, other,
# Nearest to seven: four, three, fabio, bayer, nine, sherlock, zaire, precaution,
# Nearest to also: roque, rust, will, expandable, sacrificed, dies, highest, cctld,
# Nearest to institute: sultanates, candle, cooperate, harmon, objections, talia, commercial, cz,
# Nearest to placed: sophisticated, kushner, piazza, superclass, capet, administers, ie, consensus,
# Nearest to square: verner, fired, tiberius, catheter, conscience, unexplainable, paradox, angst,
# Nearest to arts: approaches, anglo, emmy, generalized, postwar, whipped, role, limelight,
# Nearest to applications: advisory, subordinate, manually, twigs, elsevier, methodical, rol, closely,
# Nearest to woman: greene, opening, hyatt, depose, ahmet, delicately, portray, ancients,
# Nearest to magazine: bottles, chemically, faye, midshipman, kitty, surrounding, dalek, rams,
# Nearest to scale: euler, lookout, bolshevik, dvina, freeware, volker, idiom, insular,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6738 0.0324 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6352 0.0320 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6287 0.0325 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6352 0.0326 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6509 0.0328 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6667 0.0324 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6160 0.0244 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5281 0.0317 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5161 0.0326 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5041 0.0315 sec/batch
# Nearest to however: everything, fg, bows, tuscan, ayla, apg, pretext, paraphrase,
# Nearest to than: form, inventive, swingarm, azo, genosha, attribution, repression, transportation,
# Nearest to who: immigrant, pequod, brownie, chapel, attitudes, loi, mayo, programmes,
# Nearest to been: majors, munich, a, fees, backer, suit, fastened, eschrichtius,
# Nearest to in: loyal, spellings, reintroduce, namely, satanism, intimidating, difference, rigoletto,
# Nearest to has: parishes, other, larp, influence, hind, equivocal, treaties, wal,
# Nearest to seven: four, three, six, nine, richard, fabio, anthony, joseph,
# Nearest to also: roque, rust, expandable, will, cctld, sacrificed, highest, ori,
# Nearest to institute: sultanates, harmon, talia, commercial, cooperate, candle, cz, conan,
# Nearest to placed: sophisticated, capet, piazza, superclass, recording, kushner, ie, alu,
# Nearest to square: verner, fired, affiliates, unexplainable, mi, tiberius, catheter, angst,
# Nearest to arts: anglo, whipped, postwar, emmy, approaches, role, usurpation, limelight,
# Nearest to applications: advisory, manually, subordinate, rol, methodical, absolute, penicillin, twigs,
# Nearest to woman: greene, hyatt, opening, depose, ahmet, delicately, portray, at,
# Nearest to magazine: bottles, chemically, faye, versus, midshipman, rams, kitty, galicia,
# Nearest to scale: freeware, lookout, touman, used, idiom, euler, ruud, warranty,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4967 0.0331 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4928 0.0323 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4635 0.0322 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4949 0.0340 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4612 0.0325 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4732 0.0326 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4638 0.0324 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3931 0.0323 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4254 0.0335 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4165 0.0326 sec/batch
# Nearest to however: fg, everything, bows, tuscan, pretext, ayla, paraphrase, apg,
# Nearest to than: form, swingarm, levels, azo, radioactive, attribution, inventive, indicators,
# Nearest to who: brownie, immigrant, chapel, pequod, loi, gales, programmes, luka,
# Nearest to been: majors, munich, a, backer, fees, eschrichtius, repeal, frustrating,
# Nearest to in: reintroduce, spellings, namely, loyal, difference, auschwitz, rigoletto, brasileira,
# Nearest to has: parishes, larp, other, equivocal, customs, influence, are, drm,
# Nearest to seven: four, three, bayer, fabio, six, lucid, capella, soyuz,
# Nearest to also: roque, rust, expandable, cctld, sacrificed, tunguska, visual, geographic,
# Nearest to institute: sultanates, harmon, talia, technology, commercial, cz, cambridge, conan,
# Nearest to placed: alu, capet, sophisticated, piazza, superclass, kushner, firth, recording,
# Nearest to square: mi, affiliates, unexplainable, fired, verner, angst, porpoises, tiberius,
# Nearest to arts: emmy, usurpation, whipped, postwar, role, limelight, anglo, approaches,
# Nearest to applications: advisory, manually, rol, oxidizing, subordinate, methodical, penicillin, hardness,
# Nearest to woman: greene, depose, hyatt, opening, portray, delicately, ahmet, isaiah,
# Nearest to magazine: bottles, faye, chemically, versus, midshipman, galicia, kitty, hyperfocal,
# Nearest to scale: freeware, touman, used, soiled, minivan, warranty, lookout, dvina,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4460 0.0336 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4511 0.0328 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4304 0.0332 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3980 0.0319 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4177 0.0330 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4449 0.0318 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3800 0.0329 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3739 0.0317 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4046 0.0321 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3701 0.0334 sec/batch
# Nearest to however: everything, fg, bows, tuscan, apg, attacked, pretext, ayla,
# Nearest to than: form, inventive, swingarm, indicators, azo, radioactive, datasets, clos,
# Nearest to who: brownie, chapel, obligation, luka, loi, immigrant, programmes, gales,
# Nearest to been: majors, fees, backer, a, munich, rescues, repeal, southend,
# Nearest to in: spellings, brasileira, reintroduce, namely, difference, loyal, rigoletto, auschwitz,
# Nearest to has: parishes, other, equivocal, larp, officeholders, emulsion, concepts, customs,
# Nearest to seven: four, three, six, bayer, nine, two, lucid, fabio,
# Nearest to also: roque, rust, expandable, cctld, sacrificed, chrism, features, tunguska,
# Nearest to institute: sultanates, technology, harmon, talia, commercial, cambridge, university, cz,
# Nearest to placed: sophisticated, alu, deceived, superclass, altering, piazza, capet, firth,
# Nearest to square: mi, affiliates, fired, porpoises, wave, verner, unexplainable, papiamento,
# Nearest to arts: emmy, acad, usurpation, postwar, limelight, apprentice, role, whipped,
# Nearest to applications: manually, advisory, rol, chip, hardness, triglycerides, donor, conductance,
# Nearest to woman: greene, depose, opening, hyatt, portray, delicately, renderings, dark,
# Nearest to magazine: bottles, faye, galicia, hyperfocal, unconventional, midshipman, masters, kitty,
# Nearest to scale: touman, freeware, warranty, minivan, taxing, soiled, lookout, used,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3894 0.0343 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4348 0.0336 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3630 0.0324 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3628 0.0330 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4144 0.0330 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3772 0.0321 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4095 0.0327 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3717 0.0328 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3472 0.0323 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3488 0.0308 sec/batch
# Nearest to however: fg, everything, tuscan, bows, pretext, ayla, apg, imposing,
# Nearest to than: form, inventive, indicators, swingarm, radioactive, azo, attribution, datasets,
# Nearest to who: obligation, brownie, luka, chapel, pequod, loi, immigrant, gales,
# Nearest to been: majors, fees, backer, a, munich, repeal, chiefdoms, amphetamines,
# Nearest to in: brasileira, reintroduce, spellings, difference, loyal, namely, rigoletto, furthest,
# Nearest to has: parishes, other, equivocal, larp, officeholders, are, concepts, free,
# Nearest to seven: four, three, six, two, nine, bayer, runways, zero,
# Nearest to also: rust, roque, cctld, chrism, new, nasdaq, motivational, features,
# Nearest to institute: sultanates, technology, commercial, talia, university, harmon, cambridge, cz,
# Nearest to placed: superclass, alu, deceived, capet, thermostat, sophisticated, little, firth,
# Nearest to square: mi, affiliates, wave, porpoises, feet, unexplainable, papiamento, verner,
# Nearest to arts: emmy, acad, usurpation, apprentice, role, postwar, limelight, alongside,
# Nearest to applications: manually, advisory, rol, subnet, chip, triglycerides, oxidizing, font,
# Nearest to woman: depose, greene, hyatt, dark, opening, delicately, portray, renderings,
# Nearest to magazine: bottles, faye, hyperfocal, unconventional, galicia, masters, midshipman, vermin,
# Nearest to scale: taxing, freeware, minivan, touman, soiled, warranty, fragility, dvina,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3422 0.0342 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3136 0.0312 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3806 0.0317 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3804 0.0329 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3868 0.0321 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2762 0.0329 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3087 0.0329 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3335 0.0322 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2549 0.0325 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3183 0.0334 sec/batch
# Nearest to however: fg, everything, bows, ayla, pretext, tuscan, apg, sarpedon,
# Nearest to than: indicators, swingarm, form, radioactive, inventive, azo, datasets, transmissions,
# Nearest to who: luka, brownie, chapel, pequod, obligation, loi, immigrant, gales,
# Nearest to been: majors, backer, fees, munich, chiefdoms, ideally, a, amphetamines,
# Nearest to in: brasileira, difference, reintroduce, spellings, donating, furthest, auschwitz, prerogative,
# Nearest to has: parishes, other, larp, improvised, partners, equivocal, influence, officeholders,
# Nearest to seven: four, three, six, two, nine, zero, bayer, runways,
# Nearest to also: rust, cctld, roque, nasdaq, features, chrism, aria, multiethnic,
# Nearest to institute: technology, sultanates, university, harmon, cambridge, commercial, talia, sciences,
# Nearest to placed: capet, alu, deceived, thermostat, superclass, firth, outlays, altering,
# Nearest to square: mi, affiliates, feet, papiamento, wave, porpoises, islets, fired,
# Nearest to arts: acad, emmy, usurpation, alongside, role, hygienic, whipped, apprentice,
# Nearest to applications: manually, advisory, subnet, chip, triglycerides, semiconductor, rol, font,
# Nearest to woman: depose, greene, hyatt, dark, delicately, renderings, poisoned, portray,
# Nearest to magazine: bottles, hyperfocal, faye, unconventional, galicia, masters, midshipman, vermin,
# Nearest to scale: warranty, taxing, touman, freeware, soiled, fragility, minivan, dvina,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3038 0.0333 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3304 0.0331 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3368 0.0152 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2876 0.0322 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2531 0.0325 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2586 0.0326 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2139 0.0313 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2131 0.0325 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2337 0.0321 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1792 0.0312 sec/batch
# Nearest to however: fg, everything, bows, apg, pretext, imposing, tuscan, ayla,
# Nearest to than: indicators, form, swingarm, inventive, radioactive, genosha, azo, datasets,
# Nearest to who: pequod, chapel, luka, brownie, obligation, loi, programmes, immigrant,
# Nearest to been: backer, majors, chiefdoms, munich, a, fees, ideally, patronage,
# Nearest to in: brasileira, difference, auschwitz, furthest, donating, spellings, reintroduce, prerogative,
# Nearest to has: larp, other, parishes, partners, free, wal, are, improvised,
# Nearest to seven: four, three, six, two, nine, zero, five, bayer,
# Nearest to also: rust, cctld, nasdaq, roque, americas, features, naboth, multiethnic,
# Nearest to institute: technology, university, sultanates, talia, commercial, sciences, harmon, cambridge,
# Nearest to placed: capet, firth, deceived, rust, piazza, slippage, outlays, disgraced,
# Nearest to square: mi, affiliates, feet, islets, papiamento, wave, porpoises, metres,
# Nearest to arts: acad, emmy, alongside, role, usurpation, apprentice, hygienic, limelight,
# Nearest to applications: manually, advisory, subnet, font, rol, chip, gimp, gaming,
# Nearest to woman: depose, greene, hyatt, delicately, poisoned, dark, kulin, renderings,
# Nearest to magazine: bottles, hyperfocal, faye, masters, unconventional, vermin, midshipman, galicia,
# Nearest to scale: tone, warranty, freeware, taxing, touman, dvina, soiled, idiom,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2482 0.0335 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2159 0.0334 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2445 0.0340 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1652 0.0322 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1884 0.0325 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1728 0.0330 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1543 0.0321 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2044 0.0331 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1994 0.0321 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1656 0.0318 sec/batch
# Nearest to however: fg, everything, bows, apg, attacked, pretext, tuscan, sarpedon,
# Nearest to than: indicators, form, inventive, swingarm, datasets, perception, genosha, radioactive,
# Nearest to who: luka, pequod, chapel, obligation, brownie, programmes, loi, gales,
# Nearest to been: backer, a, ideally, chiefdoms, majors, munich, patronage, understand,
# Nearest to in: difference, brasileira, furthest, spellings, sylia, prerogative, donating, plane,
# Nearest to has: parishes, other, emulsion, larp, bardic, free, equivocal, concepts,
# Nearest to seven: four, three, six, two, nine, zero, bayer, runways,
# Nearest to also: rust, cctld, nasdaq, roque, features, multiethnic, aria, chrism,
# Nearest to institute: technology, university, sciences, sultanates, cambridge, harmon, talia, commercial,
# Nearest to placed: firth, deceived, slippage, rust, capet, spool, outlays, alu,
# Nearest to square: mi, affiliates, feet, islets, papiamento, wave, porpoises, angst,
# Nearest to arts: acad, alongside, emmy, limelight, apprentice, usurpation, conflagration, whipped,
# Nearest to applications: manually, advisory, subnet, font, oxidizing, rol, gaming, gimp,
# Nearest to woman: depose, hyatt, delicately, greene, kulin, poisoned, sandow, portray,
# Nearest to magazine: bottles, hyperfocal, faye, masters, unconventional, vermin, midshipman, eubank,
# Nearest to scale: warranty, taxing, soiled, tone, touman, garnet, minivan, freeware,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1900 0.0335 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2443 0.0324 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1790 0.0319 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1653 0.0333 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1946 0.0331 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1559 0.0323 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2114 0.0321 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1752 0.0332 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1459 0.0331 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1506 0.0333 sec/batch
# Nearest to however: everything, fg, bows, apg, imposing, disregarded, tuscan, attacked,
# Nearest to than: indicators, inventive, datasets, form, swingarm, perception, clos, genosha,
# Nearest to who: luka, pequod, brownie, programmes, obligation, chapel, loi, immigrant,
# Nearest to been: backer, ideally, a, chiefdoms, majors, understand, munich, outpouring,
# Nearest to in: brasileira, furthest, difference, sylia, prerogative, cappella, spellings, attending,
# Nearest to has: free, emulsion, other, equivocal, concepts, decreasing, parishes, bardic,
# Nearest to seven: four, three, six, nine, two, zero, five, runways,
# Nearest to also: rust, cctld, nasdaq, features, toolkit, chrism, eph, motivational,
# Nearest to institute: technology, university, sciences, cambridge, sultanates, commercial, talia, harmon,
# Nearest to placed: firth, deceived, slippage, rust, sassanians, alu, outlays, capet,
# Nearest to square: affiliates, mi, feet, papiamento, islets, wave, porpoises, angst,
# Nearest to arts: acad, emmy, alongside, berkman, limelight, role, conflagration, apprentice,
# Nearest to applications: manually, subnet, advisory, linux, gimp, rol, font, oxidizing,
# Nearest to woman: depose, hyatt, poisoned, sandow, kulin, dark, renderings, greene,
# Nearest to magazine: bottles, hyperfocal, masters, faye, unconventional, bukowski, galicia, physica,
# Nearest to scale: taxing, soiled, warranty, tone, idiom, garnet, mitochondrion, touman,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2116 0.0339 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.2114 0.0319 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1911 0.0310 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1973 0.0314 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1451 0.0329 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1295 0.0314 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1714 0.0321 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1470 0.0314 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1993 0.0334 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2199 0.0339 sec/batch
# Nearest to however: fg, everything, bows, apg, pretext, tuscan, imposing, attacked,
# Nearest to than: indicators, inventive, genosha, datasets, gandhi, swingarm, clos, form,
# Nearest to who: luka, brownie, pequod, obligation, programmes, chapel, immigrant, loi,
# Nearest to been: backer, a, munich, chiefdoms, majors, patronage, outpouring, understand,
# Nearest to in: brasileira, of, prerogative, sylia, furthest, after, playoffs, althea,
# Nearest to has: parishes, emulsion, concepts, free, larp, equivocal, monotone, improvised,
# Nearest to seven: four, three, six, nine, two, zero, five, one,
# Nearest to also: rust, cctld, nasdaq, chrism, motivational, americas, new, eph,
# Nearest to institute: technology, university, sciences, commercial, sultanates, cambridge, harmon, lemelson,
# Nearest to placed: deceived, firth, invictus, capet, sassanians, slippage, thermostat, bait,
# Nearest to square: mi, affiliates, feet, papiamento, islets, wave, porpoises, michell,
# Nearest to arts: acad, alongside, emmy, role, berkman, alastair, freshman, conflagration,
# Nearest to applications: manually, advisory, subnet, linux, gimp, methodical, oxidizing, sussman,
# Nearest to woman: depose, hyatt, poisoned, sandow, dark, female, renderings, birth,
# Nearest to magazine: bottles, hyperfocal, masters, bukowski, faye, kadima, wheaton, lawns,
# Nearest to scale: taxing, tone, soiled, warranty, garnet, idiom, mitochondrion, touman,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2508 0.0328 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1318 0.0308 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1647 0.0320 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1595 0.0312 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0424 0.0336 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1552 0.0328 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1717 0.0332 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1488 0.0320 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.2017 0.0065 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1259 0.0332 sec/batch
# Nearest to however: fg, everything, bows, apg, pretext, tuscan, strontium, idiomatic,
# Nearest to than: indicators, swingarm, genosha, inventive, datasets, clos, depreciation, gandhi,
# Nearest to who: pequod, luka, brownie, obligation, programmes, contraceptive, chapel, immigrant,
# Nearest to been: backer, munich, a, majors, dobson, chiefdoms, tae, ideally,
# Nearest to in: donating, furthest, difference, sylia, of, dominating, prerogative, instrumentation,
# Nearest to has: other, parishes, concepts, partners, emulsion, decreasing, free, influence,
# Nearest to seven: four, three, six, two, nine, zero, five, one,
# Nearest to also: rust, cctld, nasdaq, americas, features, ori, aria, multiethnic,
# Nearest to institute: technology, university, sciences, commercial, sultanates, lemelson, harmon, cambridge,
# Nearest to placed: deceived, firth, capet, invictus, slippage, sassanians, rust, bait,
# Nearest to square: mi, affiliates, islets, feet, papiamento, porpoises, michell, wave,
# Nearest to arts: acad, alongside, role, conflagration, emmy, freshman, hygienic, berkman,
# Nearest to applications: manually, subnet, advisory, linux, sussman, gimp, oxidizing, lucent,
# Nearest to woman: depose, hyatt, sandow, female, birth, poisoned, disfigured, nationality,
# Nearest to magazine: bottles, hyperfocal, bukowski, kadima, faye, masters, calif, books,
# Nearest to scale: tone, taxing, idiom, garnet, warranty, soiled, frets, fragility,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0981 0.0345 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0925 0.0319 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0920 0.0319 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0900 0.0311 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0809 0.0337 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0568 0.0313 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1213 0.0318 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0969 0.0300 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1263 0.0328 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0515 0.0316 sec/batch
# Nearest to however: fg, everything, bows, apg, imposing, pretext, disregarded, paraphrase,
# Nearest to than: indicators, swingarm, genosha, datasets, clos, inventive, form, draftees,
# Nearest to who: luka, brownie, pequod, programmes, contraceptive, chapel, obligation, prophesied,
# Nearest to been: backer, munich, ideally, tae, gematria, responses, extremophiles, majors,
# Nearest to in: sylia, furthest, of, donating, cappella, playoffs, dominating, which,
# Nearest to has: parishes, other, partners, concepts, polytechnique, are, today, emulsion,
# Nearest to seven: four, three, six, two, nine, zero, five, one,
# Nearest to also: rust, cctld, nasdaq, americas, eph, multiethnic, systems, features,
# Nearest to institute: university, technology, sciences, sultanates, commercial, universities, lemelson, cambridge,
# Nearest to placed: deceived, capet, firth, invictus, slippage, piazza, sassanians, rust,
# Nearest to square: mi, affiliates, islets, feet, papiamento, michell, porpoises, metres,
# Nearest to arts: acad, alongside, role, freshman, conflagration, alastair, berkman, emmy,
# Nearest to applications: manually, subnet, advisory, sussman, linux, oxidizing, hardness, thumbnails,
# Nearest to woman: depose, hyatt, poisoned, disfigured, birth, sandow, female, nationality,
# Nearest to magazine: bottles, hyperfocal, bukowski, faye, kadima, calif, masters, wheaton,
# Nearest to scale: tone, taxing, idiom, garnet, soiled, warranty, frets, prohibitive,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0094 0.0335 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0538 0.0334 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0258 0.0330 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0848 0.0330 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.1018 0.0307 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0565 0.0341 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0750 0.0333 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0856 0.0330 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0698 0.0337 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0625 0.0320 sec/batch
# Nearest to however: everything, apg, bows, fg, strontium, disregarded, imposing, attacked,
# Nearest to than: indicators, datasets, clos, swingarm, inventive, depreciation, form, childe,
# Nearest to who: brownie, luka, pequod, contraceptive, programmes, obligation, chapel, replicator,
# Nearest to been: backer, extremophiles, dobson, munich, gematria, ideally, hanja, responses,
# Nearest to in: sylia, of, difference, which, organisation, donating, referred, enrollments,
# Nearest to has: emulsion, other, decreasing, concepts, parishes, chd, partners, bardic,
# Nearest to seven: four, three, six, two, nine, zero, five, one,
# Nearest to also: rust, cctld, eph, nasdaq, americas, chrism, ori, motivational,
# Nearest to institute: university, technology, sciences, commercial, lemelson, sultanates, universities, cambridge,
# Nearest to placed: capet, deceived, firth, slippage, alu, rust, spool, invictus,
# Nearest to square: affiliates, islets, mi, feet, porpoises, papiamento, michell, metres,
# Nearest to arts: acad, alongside, freshman, role, alastair, berkman, campus, conflagration,
# Nearest to applications: manually, subnet, advisory, oxidizing, hardness, sussman, thumbnails, ckel,
# Nearest to woman: depose, hyatt, nationality, female, disfigured, sandow, daughters, poisoned,
# Nearest to magazine: bottles, hyperfocal, kadima, bukowski, masters, condiments, calif, sunnyvale,
# Nearest to scale: taxing, tone, garnet, idiom, soiled, warranty, mitochondrion, frets,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.1029 0.0332 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1024 0.0329 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1031 0.0324 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0642 0.0323 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0872 0.0324 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0628 0.0318 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0881 0.0302 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0624 0.0323 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0904 0.0315 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0759 0.0313 sec/batch
# Nearest to however: everything, bows, imposing, fg, attacked, disregarded, apg, pretext,
# Nearest to than: indicators, datasets, swingarm, clos, inventive, genosha, depreciation, childe,
# Nearest to who: luka, brownie, pequod, obligation, contraceptive, suspicion, programmes, hopes,
# Nearest to been: backer, extremophiles, munich, dobson, hanja, gematria, a, outpouring,
# Nearest to in: of, which, after, sylia, furthest, prerogative, consanguinity, donating,
# Nearest to has: emulsion, other, concepts, chd, parishes, polytechnique, monotone, bardic,
# Nearest to seven: four, three, nine, six, two, zero, five, one,
# Nearest to also: cctld, americas, chrism, rust, eph, ori, washburn, motivational,
# Nearest to institute: university, technology, sciences, commercial, lemelson, universities, sultanates, cambridge,
# Nearest to placed: deceived, capet, firth, invictus, piazza, outlays, slippage, alu,
# Nearest to square: affiliates, mi, islets, feet, papiamento, michell, porpoises, verner,
# Nearest to arts: acad, freshman, alongside, role, alastair, berkman, campus, conflagration,
# Nearest to applications: advisory, subnet, manually, gimp, oxidizing, hardness, sussman, thumbnails,
# Nearest to woman: depose, nationality, hyatt, female, sandow, poisoned, birth, male,
# Nearest to magazine: bottles, hyperfocal, books, sunnyvale, faye, condiments, essay, kadima,
# Nearest to scale: taxing, soiled, garnet, tone, idiom, frets, warranty, mitochondrion,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0880 0.0315 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0164 0.0290 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0515 0.0293 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0617 0.0295 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0997 0.0287 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1260 0.0288 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1528 0.0285 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0577 0.0288 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0462 0.0284 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0586 0.0285 sec/batch
# Nearest to however: bows, everything, pretext, fg, apg, strontium, attacked, paraphrase,
# Nearest to than: indicators, swingarm, istat, embolism, datasets, childe, gandhi, depreciation,
# Nearest to who: brownie, luka, pequod, contraceptive, obligation, hopes, suspicion, programmes,
# Nearest to been: hanja, backer, dobson, extremophiles, munich, gematria, responses, outpouring,
# Nearest to in: of, after, furthest, on, which, donating, sylia, playoffs,
# Nearest to has: parishes, chd, decreasing, emulsion, other, polytechnique, are, partners,
# Nearest to seven: four, three, six, two, nine, zero, five, one,
# Nearest to also: cctld, rust, americas, nasdaq, chrism, washburn, eph, multiethnic,
# Nearest to institute: university, technology, sciences, lemelson, commercial, botanists, universities, sultanates,
# Nearest to placed: deceived, capet, invictus, piazza, slippage, firth, gambled, hauling,
# Nearest to square: affiliates, mi, feet, islets, papiamento, michell, porpoises, assuage,
# Nearest to arts: acad, freshman, alongside, campus, conflagration, alastair, role, graduate,
# Nearest to applications: subnet, advisory, gimp, manually, sussman, hardness, realign, elsevier,
# Nearest to woman: nationality, depose, hyatt, female, male, birth, fertility, expectancy,
# Nearest to magazine: bottles, kadima, hyperfocal, sunnyvale, calif, books, condiments, essay,
# Nearest to scale: taxing, tone, garnet, soiled, idiom, frets, warranty, mitochondrion,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9944 0.0297 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0773 0.0287 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0551 0.0290 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0595 0.0292 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.1324 0.0293 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0808 0.0273 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0222 0.0289 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0118 0.0290 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0223 0.0289 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9770 0.0292 sec/batch
# Nearest to however: bows, apg, fg, everything, paraphrase, pretext, strontium, move,
# Nearest to than: datasets, indicators, swingarm, childe, istat, embolism, clos, depreciation,
# Nearest to who: luka, brownie, pequod, contraceptive, obligation, prophecies, replicator, suspicion,
# Nearest to been: hanja, backer, extremophiles, dobson, stillwater, squat, munich, responses,
# Nearest to in: of, which, after, on, a, furthest, donating, enrollments,
# Nearest to has: today, emulsion, chd, concepts, parishes, other, partners, spooky,
# Nearest to seven: four, three, six, nine, two, five, zero, one,
# Nearest to also: rust, cctld, chrism, visual, nasdaq, americas, motivational, aficionados,
# Nearest to institute: university, technology, lemelson, commercial, sciences, sultanates, botanists, harmon,
# Nearest to placed: deceived, invictus, capet, piazza, firth, slippage, gambled, bait,
# Nearest to square: affiliates, mi, feet, islets, porpoises, michell, papiamento, corner,
# Nearest to arts: acad, freshman, alongside, conflagration, campus, role, alastair, berkman,
# Nearest to applications: subnet, manually, gimp, advisory, hardness, font, thumbnails, sussman,
# Nearest to woman: nationality, depose, hyatt, birth, female, sandow, male, fertility,
# Nearest to magazine: kadima, bottles, calif, hyperfocal, sunnyvale, essay, condiments, faye,
# Nearest to scale: tone, taxing, frets, garnet, idiom, soiled, warranty, zach,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9902 0.0298 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9572 0.0290 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0294 0.0288 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0279 0.0288 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0150 0.0286 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0310 0.0286 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9263 0.0286 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9684 0.0286 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9524 0.0286 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9940 0.0286 sec/batch
# Nearest to however: apg, bows, everything, strontium, paraphrase, fg, move, disregarded,
# Nearest to than: indicators, embolism, swingarm, datasets, istat, slower, childe, depreciation,
# Nearest to who: brownie, luka, contraceptive, pequod, prophecies, realising, accordingly, prophesied,
# Nearest to been: hanja, backer, extremophiles, munich, stillwater, a, ideally, tae,
# Nearest to in: of, playoffs, after, a, the, which, and, on,
# Nearest to has: concepts, today, emulsion, parishes, free, decreasing, other, spooky,
# Nearest to seven: four, three, six, two, nine, zero, five, one,
# Nearest to also: rust, cctld, americas, aficionados, eph, motivational, bike, washburn,
# Nearest to institute: technology, university, sciences, lemelson, universities, botanists, sultanates, commercial,
# Nearest to placed: deceived, invictus, gambled, piazza, capet, bait, slippage, fuse,
# Nearest to square: affiliates, islets, mi, feet, porpoises, michell, corner, metres,
# Nearest to arts: acad, freshman, alongside, alastair, campus, conflagration, role, berkman,
# Nearest to applications: hardness, subnet, advisory, manually, gimp, thumbnails, culbert, enhancers,
# Nearest to woman: nationality, depose, hyatt, female, male, fertility, birth, daughters,
# Nearest to magazine: bottles, kadima, hyperfocal, essay, calif, sunnyvale, agitating, condiments,
# Nearest to scale: taxing, tone, garnet, soiled, idiom, frets, warranty, impartial,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0421 0.0296 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9981 0.0285 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9509 0.0285 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0170 0.0285 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0645 0.0286 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9779 0.0288 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0136 0.0292 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0078 0.0288 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0021 0.0290 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0169 0.0289 sec/batch
# Nearest to however: everything, bows, congratulations, strontium, paraphrase, apg, disregarded, pretext,
# Nearest to than: datasets, indicators, embolism, swingarm, slower, istat, clos, depreciation,
# Nearest to who: brownie, luka, contraceptive, pequod, realising, noticed, obligation, prophecies,
# Nearest to been: hanja, extremophiles, backer, responses, dobson, gematria, stillwater, outpouring,
# Nearest to in: of, a, the, on, after, which, playoffs, repeated,
# Nearest to has: emulsion, spooky, eastenders, concepts, today, wal, despite, monotone,
# Nearest to seven: four, three, nine, six, two, zero, one, five,
# Nearest to also: rust, cctld, supplemental, chrism, motivational, eph, americas, aficionados,
# Nearest to institute: technology, university, lemelson, sciences, botanists, commercial, sultanates, universities,
# Nearest to placed: deceived, invictus, gambled, batters, slippage, fuse, bait, spool,
# Nearest to square: affiliates, islets, feet, mi, porpoises, michell, corner, assuage,
# Nearest to arts: acad, freshman, alongside, campus, alastair, role, conflagration, berkman,
# Nearest to applications: hardness, advisory, gimp, subnet, manually, culbert, enhancers, thumbnails,
# Nearest to woman: nationality, depose, hyatt, walk, she, male, fertility, birth,
# Nearest to magazine: bottles, kadima, essay, hyperfocal, sunnyvale, calif, agitating, books,
# Nearest to scale: taxing, tone, garnet, frets, soiled, idiom, warranty, falange,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0256 0.0299 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0027 0.0290 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9862 0.0290 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0321 0.0287 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0116 0.0287 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0194 0.0289 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9657 0.0291 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9420 0.0286 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9989 0.0285 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0407 0.0286 sec/batch
# Nearest to however: everything, paraphrase, continence, disregarded, bows, fg, strontium, apg,
# Nearest to than: indicators, istat, datasets, swingarm, embolism, albicans, slower, optional,
# Nearest to who: luka, brownie, contraceptive, pequod, leader, obligation, accordingly, ahl,
# Nearest to been: hanja, backer, extremophiles, dobson, outpouring, stillwater, a, responses,
# Nearest to in: of, the, after, and, which, a, on, cypriot,
# Nearest to has: emulsion, concepts, partners, today, spooky, decreasing, gays, polytechnique,
# Nearest to seven: four, three, nine, two, six, zero, five, one,
# Nearest to also: cctld, rust, motivational, hawaii, chrism, americas, washburn, maps,
# Nearest to institute: technology, university, lemelson, commercial, sciences, botanists, universities, association,
# Nearest to placed: deceived, invictus, gambled, alu, capet, bait, impetus, fuse,
# Nearest to square: affiliates, mi, feet, islets, porpoises, michell, papiamento, corner,
# Nearest to arts: acad, freshman, alongside, role, campus, sport, berkman, conflagration,
# Nearest to applications: advisory, gimp, hardness, subnet, manually, enhancers, culbert, thumbnails,
# Nearest to woman: nationality, depose, hyatt, fertility, female, male, expectancy, birth,
# Nearest to magazine: kadima, bottles, essay, hyperfocal, calif, sunnyvale, condiments, agitating,
# Nearest to scale: taxing, tone, garnet, frets, soiled, idiom, solidify, warranty,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9677 0.0298 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0725 0.0285 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0165 0.0287 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0591 0.0288 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9780 0.0285 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9723 0.0288 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9897 0.0302 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9199 0.0303 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 4.0184 0.0303 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9948 0.0300 sec/batch
# ...
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8097 0.0295 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8838 0.0294 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8579 0.0291 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8636 0.0291 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.9084 0.0292 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9144 0.0291 sec/batch
# Nearest to however: more, advertisements, mwh, labrador, kombinate, brewer, in, with,
# Nearest to than: sym, slower, and, maniera, accumulator, istat, two, more,
# Nearest to who: contraceptive, are, brownie, noticed, accordingly, sent, bofh, luka,
# Nearest to been: hanja, have, from, has, since, amphetamines, mails, frustrating,
# Nearest to in: the, of, a, and, after, by, as, for,
# Nearest to has: in, today, regatta, is, spooky, despite, of, s,
# Nearest to seven: four, three, one, two, six, zero, five, nine,
# Nearest to also: the, as, of, in, various, a, known, including,
# Nearest to institute: technology, university, sciences, associates, universities, lemelson, talia, clayton,
# Nearest to placed: mobsters, debuting, invictus, gambled, fuse, wealthiest, uncommon, unattended,
# Nearest to square: affiliates, mi, porpoises, islets, vertex, antidepressants, feet, assuage,
# Nearest to arts: fine, role, freshman, acad, cagayan, martial, permittivity, student,
# Nearest to applications: hardness, culbert, advisory, cannae, ckel, centres, dissimilar, font,
# Nearest to woman: she, nationality, dancer, prohibit, lady, herself, ebrahim, religious,
# Nearest to magazine: agitating, magazines, biodegradable, kadima, calif, essay, lifeguard, tanker,
# Nearest to scale: garnet, taxing, tone, solidify, relentless, reflectance, falange, frets,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8795 0.0301 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8805 0.0291 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8886 0.0293 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8827 0.0294 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8732 0.0293 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8937 0.0291 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8550 0.0292 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8669 0.0291 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9079 0.0291 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8921 0.0291 sec/batch
# Nearest to however: more, in, and, to, advertisements, labrador, a, with,
# Nearest to than: sym, and, slower, maniera, more, other, accumulator, istat,
# Nearest to who: are, accordingly, contraceptive, noticed, elected, brownie, profess, sent,
# Nearest to been: hanja, have, was, since, the, from, a, provided,
# Nearest to in: the, of, a, and, by, which, on, after,
# Nearest to has: despite, spooky, regatta, eastenders, is, s, today, in,
# Nearest to seven: four, three, two, five, one, six, nine, zero,
# Nearest to also: the, of, as, in, a, known, various, cctld,
# Nearest to institute: technology, university, associates, talia, sciences, lemelson, universities, commercial,
# Nearest to placed: mobsters, invictus, wealthiest, fuse, unattended, gambled, recording, uncommon,
# Nearest to square: affiliates, porpoises, vertex, mi, antidepressants, feet, islets, corner,
# Nearest to arts: role, acad, freshman, fine, martial, cagayan, permittivity, student,
# Nearest to applications: culbert, hardness, advisory, cannae, ckel, dissimilar, gimp, centres,
# Nearest to woman: nationality, she, dancer, lady, religious, herself, ebrahim, prohibit,
# Nearest to magazine: agitating, magazines, kadima, calif, biodegradable, essay, tanker, physica,
# Nearest to scale: garnet, taxing, solidify, tone, reflectance, relentless, accusations, frets,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8819 0.0302 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8734 0.0290 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8432 0.0293 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8476 0.0291 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9068 0.0294 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8449 0.0294 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.0038 0.0291 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9020 0.0292 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9443 0.0289 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8319 0.0291 sec/batch
# Nearest to however: more, a, to, and, labrador, in, with, substantial,
# Nearest to than: and, sym, gandhi, slower, more, two, of, other,
# Nearest to who: brownie, hamnett, contraceptive, accordingly, are, sent, leader, noticed,
# Nearest to been: have, hanja, was, there, the, a, from, since,
# Nearest to in: the, of, a, and, on, after, which, for,
# Nearest to has: is, despite, regatta, s, spooky, of, polytechnique, today,
# Nearest to seven: four, three, two, five, one, six, nine, zero,
# Nearest to also: the, of, as, in, a, other, such, known,
# Nearest to institute: technology, university, associates, sciences, talia, lemelson, commercial, freemasons,
# Nearest to placed: unattended, fuse, wealthiest, mobsters, invictus, gambled, uncommon, piazza,
# Nearest to square: affiliates, mi, porpoises, vertex, feet, antidepressants, idaho, metres,
# Nearest to arts: acad, role, martial, fine, freshman, fu, permittivity, wushu,
# Nearest to applications: culbert, advisory, hardness, linux, centres, gimp, cannae, dissimilar,
# Nearest to woman: nationality, she, dancer, prohibit, ebrahim, religious, lady, fertility,
# Nearest to magazine: agitating, magazines, biodegradable, kadima, essay, calif, tanker, lifeguard,
# Nearest to scale: garnet, taxing, solidify, tone, accusations, relentless, reflectance, falange,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7898 0.0301 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8861 0.0291 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8265 0.0291 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.9017 0.0293 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8382 0.0291 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8709 0.0293 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9023 0.0168 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8577 0.0292 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8708 0.0292 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8679 0.0293 sec/batch
# Nearest to however: more, a, and, advertisements, labrador, to, brewer, michelson,
# Nearest to than: and, sym, slower, accumulator, is, gandhi, maniera, other,
# Nearest to who: sent, accordingly, hamnett, contraceptive, grandson, brownie, seiya, expiry,
# Nearest to been: have, was, hanja, from, remains, a, mails, the,
# Nearest to in: the, of, a, and, by, on, for, as,
# Nearest to has: is, today, regatta, spooky, despite, s, consistent, dalla,
# Nearest to seven: four, three, two, one, five, six, nine, zero,
# Nearest to also: as, the, of, in, known, various, other, is,
# Nearest to institute: technology, university, associates, sciences, talia, lemelson, commercial, clayton,
# Nearest to placed: invictus, wealthiest, unattended, fuse, mobsters, uncommon, piazza, softwood,
# Nearest to square: affiliates, mi, porpoises, vertex, antidepressants, metres, feet, islets,
# Nearest to arts: role, martial, acad, fine, kicks, fu, freshman, wushu,
# Nearest to applications: hardness, advisory, culbert, centres, linux, cannae, gimp, caterpillars,
# Nearest to woman: nationality, she, religious, ebrahim, prohibit, dancer, lady, intercourse,
# Nearest to magazine: agitating, magazines, biodegradable, kadima, essay, calif, yakov, tanker,
# Nearest to scale: garnet, tone, taxing, solidify, frets, reflectance, relentless, falange,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8390 0.0304 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8181 0.0291 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8451 0.0292 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8258 0.0291 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8895 0.0291 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8767 0.0295 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.9220 0.0292 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7467 0.0293 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8278 0.0291 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8353 0.0292 sec/batch
# Nearest to however: more, in, a, and, to, with, labrador, such,
# Nearest to than: and, two, is, sym, more, slower, or, accumulator,
# Nearest to who: brownie, accordingly, contraceptive, sent, are, hamnett, interestingly, expiry,
# Nearest to been: have, was, from, hanja, remains, since, there, mails,
# Nearest to in: the, and, of, a, for, as, by, on,
# Nearest to has: today, despite, is, the, in, regatta, and, s,
# Nearest to seven: four, three, five, two, six, one, zero, nine,
# Nearest to also: the, in, of, as, and, a, known, including,
# Nearest to institute: technology, university, sciences, associates, talia, lemelson, commercial, reclaiming,
# Nearest to placed: mobsters, unattended, wealthiest, invictus, fuse, softwood, debuting, gambled,
# Nearest to square: affiliates, mi, porpoises, metres, feet, vertex, islets, assuage,
# Nearest to arts: role, martial, fine, acad, freshman, fu, wushu, kicks,
# Nearest to applications: hardness, culbert, centres, advisory, ckel, cannae, rol, linux,
# Nearest to woman: nationality, she, prohibit, ebrahim, dancer, religious, herself, lady,
# Nearest to magazine: agitating, magazines, biodegradable, kadima, calif, essay, lifeguard, yakov,
# Nearest to scale: garnet, tone, taxing, solidify, relentless, falange, fragility, accusations,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7834 0.0303 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8501 0.0291 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8622 0.0290 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8343 0.0293 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8268 0.0291 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9240 0.0291 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8309 0.0294 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8498 0.0296 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8418 0.0293 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8510 0.0291 sec/batch
# Nearest to however: more, a, in, with, and, brewer, to, advertisements,
# Nearest to than: and, not, sym, is, other, slower, an, two,
# Nearest to who: are, brownie, accordingly, contraceptive, interestingly, leader, noticed, profess,
# Nearest to been: have, was, from, a, since, hanja, the, mails,
# Nearest to in: the, a, of, and, for, as, on, also,
# Nearest to has: is, in, the, and, of, today, despite, s,
# Nearest to seven: four, three, two, one, six, five, zero, nine,
# Nearest to also: the, of, in, as, a, and, known, such,
# Nearest to institute: technology, university, sciences, associates, talia, lemelson, commercial, universities,
# Nearest to placed: unattended, mobsters, invictus, wealthiest, fuse, softwood, recording, debuting,
# Nearest to square: affiliates, mi, feet, vertex, porpoises, metres, antidepressants, residing,
# Nearest to arts: fine, freshman, martial, acad, role, sciences, fu, student,
# Nearest to applications: culbert, hardness, centres, advisory, rol, cannae, ckel, dissimilar,
# Nearest to woman: nationality, she, dancer, lady, herself, religious, ebrahim, sandow,
# Nearest to magazine: agitating, magazines, biodegradable, kadima, essay, calif, lifeguard, pseudonym,
# Nearest to scale: garnet, tone, taxing, solidify, relentless, falange, accusations, inspire,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8872 0.0307 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8823 0.0297 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8433 0.0297 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8700 0.0291 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8910 0.0291 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8512 0.0296 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8561 0.0299 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8888 0.0306 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8410 0.0298 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8609 0.0297 sec/batch
# Nearest to however: more, a, in, to, and, with, as, refused,
# Nearest to than: and, other, not, is, more, slower, two, an,
# Nearest to who: profess, brownie, are, accordingly, their, leader, appreciating, expiry,
# Nearest to been: have, the, from, was, since, there, a, has,
# Nearest to in: the, of, and, a, as, by, on, which,
# Nearest to has: is, in, the, of, and, s, as, have,
# Nearest to seven: four, three, five, two, one, nine, six, zero,
# Nearest to also: the, of, in, as, a, and, with, such,
# Nearest to institute: technology, university, sciences, talia, associates, commercial, lemelson, clayton,
# Nearest to placed: unattended, invictus, mobsters, below, wealthiest, fuse, capet, softwood,
# Nearest to square: affiliates, mi, feet, porpoises, vertex, residing, algorithms, metres,
# Nearest to arts: freshman, fine, martial, role, acad, fu, sciences, wushu,
# Nearest to applications: culbert, advisory, hardness, centres, cannae, rol, yttrium, ckel,
# Nearest to woman: nationality, she, dancer, herself, ebrahim, religious, fertility, lady,
# Nearest to magazine: agitating, magazines, biodegradable, kadima, calif, utopian, essay, lifeguard,
# Nearest to scale: garnet, tone, taxing, solidify, accusations, fragility, relentless, frets,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8804 0.0307 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8490 0.0294 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9543 0.0291 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9253 0.0293 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8928 0.0292 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8482 0.0294 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7883 0.0293 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8667 0.0292 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7584 0.0292 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8735 0.0293 sec/batch
# Nearest to however: more, a, to, as, substantial, such, advertisements, in,
# Nearest to than: more, is, and, other, slower, less, not, fewer,
# Nearest to who: brownie, leader, profess, interestingly, hamnett, are, elected, choctaw,
# Nearest to been: have, was, from, hanja, since, there, has, the,
# Nearest to in: the, of, and, a, on, for, by, as,
# Nearest to has: is, in, the, of, and, s, as, are,
# Nearest to seven: four, one, three, five, two, six, nine, zero,
# Nearest to also: of, in, the, as, a, and, known, is,
# Nearest to institute: technology, university, associates, sciences, talia, lemelson, reclaiming, freemasons,
# Nearest to placed: unattended, invictus, mobsters, softwood, wealthiest, fuse, below, debuting,
# Nearest to square: affiliates, mi, feet, vertex, porpoises, algorithms, antidepressants, assuage,
# Nearest to arts: martial, fine, acad, kicks, fu, role, wushu, freshman,
# Nearest to applications: culbert, hardness, centres, cannae, yttrium, advisory, ckel, windows,
# Nearest to woman: nationality, she, ebrahim, religious, dancer, fertility, lady, prohibit,
# Nearest to magazine: agitating, magazines, biodegradable, kadima, calif, essay, column, yakov,
# Nearest to scale: garnet, tone, taxing, solidify, accusations, fragility, frets, relentless,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8658 0.0307 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8619 0.0296 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
